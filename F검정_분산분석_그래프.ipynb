# %% [markdown]
# <a href="https://colab.research.google.com/github/kwakyosong/BIO_Python/blob/main/F%EA%B2%80%EC%A0%95_%EB%B6%84%EC%82%B0%EB%B6%84%EC%84%9D_%EA%B7%B8%EB%9E%98%ED%94%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
from scipy.stats import f_oneway

# 세 가지 약물 투여 후 혈압 감소 수치 (세 그룹의 데이터)
drug_A = [12, 15, 14, 10, 13]  # 약물 A 투여 후 혈압 감소 수치
drug_B = [18, 20, 17, 19, 22]  # 약물 B 투여 후 혈압 감소 수치
drug_C = [9, 8, 12, 7, 10]     # 약물 C 투여 후 혈압 감소 수치

# F 검정 수행 (일원분산분석)
f_stat, p_value = f_oneway(drug_A, drug_B, drug_C)

# 결과 출력
print(f"F-statistic: {f_stat:.2f}")
print(f"P-value: {p_value:.4f}")

# 박스 플롯으로 데이터 분포 시각화
plt.figure(figsize=(10, 6))
plt.boxplot([drug_A, drug_B, drug_C], labels=['Drug A', 'Drug B', 'Drug C'])
plt.title("Blood Pressure Reduction by Drug Type")
plt.ylabel("Blood Pressure Reduction")
plt.xlabel("Drug Type")
plt.grid(True)

# ANOVA 결과 주석 추가 (y 값을 더 높게 설정하여 그래프와 겹치지 않도록 조정)
plt.text(1.5, max(max(drug_A), max(drug_B), max(drug_C)) + 5,  # y 좌표를 그래프와 더 멀리 떨어뜨림
         f"F-statistic: {f_stat:.2f}\nP-value: {p_value:.4f}",
         ha='center', fontsize=12, color="red", bbox=dict(facecolor='white', edgecolor='red'))

plt.show()
# Out:
# F-statistic: 34.67
# P-value: 0.0000
